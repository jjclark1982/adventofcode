# %%
from pathlib import Path
import sys
if str(Path('../..').resolve()) not in sys.path:
    sys.path.insert(0, str(Path('../..').resolve()))

from intcode import Intcode

# %%
import aocd
program = [*map(int, aocd.get_data(year=2019, day=17).split(','))]
program[:10]
# Out:
# [1, 330, 331, 332, 109, 4288, 1102, 1, 1182, 15]

# %%
program[330:335]
# Out:
# [0, 1, 1, 6, 77]

# %%
cpu = Intcode(program)

# %%
cpu.run()
# Out:
# <Intcode pc:62/4295 cycles:61063 state:Halted>

# %%
camera = cpu.get_ascii().split("\n")
camera
# Out:
# ['....................................#######..........',
#  '....................................#.....#..........',
#  '....................................#.....#..........',
#  '....................................#.....#..........',
#  '....................................#.....#..........',
#  '....................................#.....#..........',
#  '....................................#.....#..........',
#  '....................................#.....#..........',
#  '..................................#########..........',
#  '..................................#.#................',
#  '............................#########................',
#  '............................#.....#..................',
#  '............................#.....#..................',
#  '............................#.....#..................',
#  '..........................#########..................',
#  '..........................#.#........................',
# ...

# %%
import numpy as np

# %%
grid = np.array([[c for c in line] for line in camera[:-2]])
grid
# Out:
# array([['.', '.', '.', ..., '.', '.', '.'],
#        ['.', '.', '.', ..., '.', '.', '.'],
#        ['.', '.', '.', ..., '.', '.', '.'],
#        ...,
#        ['.', '.', '.', ..., '.', '.', '.'],
#        ['.', '.', '.', ..., '.', '.', '.'],
#        ['.', '.', '.', ..., '.', '.', '.']], dtype='<U1')

# %%
directions = {
    '_': np.array([ 0, 0]),
    'U': np.array([-1, 0]),
    'D': np.array([ 1, 0]),
    'R': np.array([ 0, 1]),
    'L': np.array([ 0,-1]),
}

# %%
def mark_intersections(grid):
    alignment = []
    intersections = 0
    for row in range(1, grid.shape[0]-1):
        for col in range(1, grid.shape[1]-1):
            n_scaffolds = 0
            for direction in directions.values():
                d = tuple(direction + [row, col])
                if grid[d] in ['#', '>', '<', '^', 'v']:
                    n_scaffolds += 1
            if n_scaffolds == 5:
                grid[row, col] = 'O'
            if grid[row, col] == 'O':
                intersections += 1
                alignment.append(row * col)
    return alignment
            
mark_intersections(grid)
# Out:
# [288, 340, 392, 760, 208, 1092, 1232, 960, 1596, 1512, 1496]

# %%
[''.join(line) for line in grid]
# Out:
# ['....................................#######..........',
#  '....................................#.....#..........',
#  '....................................#.....#..........',
#  '....................................#.....#..........',
#  '....................................#.....#..........',
#  '....................................#.....#..........',
#  '....................................#.....#..........',
#  '....................................#.....#..........',
#  '..................................##O######..........',
#  '..................................#.#................',
#  '............................######O##................',
#  '............................#.....#..................',
#  '............................#.....#..................',
#  '............................#.....#..................',
#  '..........................##O######..................',
#  '..........................#.#........................',
# ...

# %% [markdown]
# #### Part 1 Answer
# Run your ASCII program. **What is the sum of the alignment parameters for the scaffold intersections?**

# %%
sum(mark_intersections(grid))
# Out:
# 9876

# %% [markdown]
# ---

# %% [markdown]
# ### Part 2

# %%
program2 = program.copy()
program2[0] = 2

# %%
type(',')
# Out:
# str
