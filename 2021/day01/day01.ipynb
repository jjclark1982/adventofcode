# %%
import numpy as np

# %%
depth = np.loadtxt("input.txt", dtype=int)
depth
# Out:
# array([ 180,  152,  159, ..., 7484, 7488, 7497])

# %% [markdown]
# ### Part 1

# %%
def count_increases(a):
    return np.count_nonzero(np.diff(a) > 0)

# %% [markdown]
# #### Part 1 Answer

# %%
count_increases(depth)
# Out:
# 1529

# %% [markdown]
# ### Part 2

# %%
depth_windows = np.array([
    depth[:-2],
    depth[1:-1],
    depth[2:]
]).T
depth_windows
# Out:
# array([[ 180,  152,  159],
#        [ 152,  159,  171],
#        [ 159,  171,  178],
#        ...,
#        [7482, 7483, 7484],
#        [7483, 7484, 7488],
#        [7484, 7488, 7497]])

# %% [markdown]
# #### Part 2 Answer

# %%
window_sums = np.sum(depth_windows, axis=1)
count_increases(window_sums)
# Out:
# 1567

# %% [markdown]
# ### Visualization

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_formats = ['svg']

# %%
fig, (ax) = plt.subplots(1)
ax.set_ylabel("depth")
ax.invert_yaxis()
ax.get_xaxis().set_visible(False)

ax.plot(np.arange(len(depth)), depth, label='sonar reading')
ax.plot(np.arange(len(window_sums)) + 500, window_sums / 3, label='moving average', color='orange')
ax.legend()

plt.show()
